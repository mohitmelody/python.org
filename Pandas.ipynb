# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitmelody/python.org/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv("hello.csv")
# pandas always read sequence data
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
data = pd.read_csv("hello.csv")
data.head()
# by default first five record
# if you read some specific record so write un head
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
data.head(10)
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
# 5  2011                    A  Agriculture, Forestry and Fishing          a_0
# 6  2011                    A  Agriculture, Forestry and Fishing          a_0
# 7  2011                    A  Agriculture, Forestry and Fishing          a_0
# 8  2011                    A  Agriculture, Forestry and Fishing          a_0
# 9  2011                    A  Agriculture, Forestry and Fishing        b_1-5
#
#                                           variable  value               unit
# ...

# %%
data.tail()
# by default last five record
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 20119  2023                  all       All Industries  j_Grand_Total
# 20120  2023                  all       All Industries  j_Grand_Total
# 20121  2023                  all       All Industries  j_Grand_Total
# 20122  2023                  all       All Industries  j_Grand_Total
# 20123  2023                  all       All Industries  j_Grand_Total
#
#                           variable    value               unit
# 20119                 Total income   930995  DOLLARS(millions)
# 20120            Total expenditure   832964  DOLLARS(millions)
# 20121  Operating profit before tax   103616  DOLLARS(millions)
# 20122                 Total assets  2831894  DOLLARS(millions)
# 20123        Fixed tangible assets   681890  DOLLARS(millions)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['year', 'industry_code_ANZSIC', 'industry_name_ANZSIC', 'rme_size_grp',
#        'variable', 'value', 'unit'],
#       dtype='object')

# %%
data["industry_name_ANZSIC"]
# Out:
# 0        Agriculture, Forestry and Fishing
# 1        Agriculture, Forestry and Fishing
# 2        Agriculture, Forestry and Fishing
# 3        Agriculture, Forestry and Fishing
# 4        Agriculture, Forestry and Fishing
#                        ...
# 20119                       All Industries
# 20120                       All Industries
# 20121                       All Industries
# 20122                       All Industries
# 20123                       All Industries
# Name: industry_name_ANZSIC, Length: 20124, dtype: object

# %%
# select particular column
dt = data["industry_name_ANZSIC"]
type(dt)
# find datatype
# series
# series ko hum list convert kar skate hai
# Out:
# pandas.core.series.Series

# %%
type(data["industry_name_ANZSIC"])
# Out:
# pandas.core.series.Series

# %%
type(data[["industry_name_ANZSIC"]])
# Out:
# pandas.core.frame.DataFrame

# %%
data[["industry_name_ANZSIC","variable" ]]
# Out:
#                     industry_name_ANZSIC  \
# 0      Agriculture, Forestry and Fishing
# 1      Agriculture, Forestry and Fishing
# 2      Agriculture, Forestry and Fishing
# 3      Agriculture, Forestry and Fishing
# 4      Agriculture, Forestry and Fishing
# ...                                  ...
# 20119                     All Industries
# 20120                     All Industries
# 20121                     All Industries
# 20122                     All Industries
# 20123                     All Industries
#
#                                               variable
# 0                                        Activity unit
# 1                               Rolling mean employees
# 2                              Salaries and wages paid
# 3      Sales, government funding, grants and subsidies
# 4                                         Total income
# ...                                                ...
# 20119                                     Total income
# ...

# %%
data.dtypes
# Out:
# year                     int64
# industry_code_ANZSIC    object
# industry_name_ANZSIC    object
# rme_size_grp            object
# variable                object
# value                   object
# unit                    object
# dtype: object

# %%
data1 = pd.read_excel("SaleData.xlsx")
# print(data1)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.dtypes
# Out:
# OrderDate     datetime64[ns]
# Region                object
# Manager               object
# SalesMan              object
# Item                  object
# Units                float64
# Unit_price           float64
# Sale_amt             float64
# dtype: object

# %%
# read multiple colun select
data1[["Region", "Item"]]
# Out:
#      Region          Item
# 0      East    Television
# 1   Central  Home Theater
# 2   Central    Television
# 3   Central    Cell Phone
# 4      West    Television
# 5      East  Home Theater
# 6   Central    Television
# 7   Central    Television
# 8      West    Television
# 9      East  Home Theater
# 10  Central    Television
# 11     East  Home Theater
# 12     East  Home Theater
# 13     East    Television
# 14  Central          Desk
# 15     East   Video Games
# 16  Central  Home Theater
# 17     East    Cell Phone
# 18     East    Cell Phone
# 19  Central   Video Games
# 20  Central    Television
# 21     East   Video Games
# 22  Central  Home Theater
# 23  Central  Home Theater
# 24     East  Home Theater
# 25     West  Home Theater
# 26  Central   Video Games
# 27  Central    Television
# 28     East    Cell Phone
# 29  Central    Television
# 30  Central  Home Theater
# 31  Central          Desk
# 32     East   Video Games
# 33  Central   Video Games
# ...
